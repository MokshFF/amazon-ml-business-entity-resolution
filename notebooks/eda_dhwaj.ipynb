# %% [markdown]
# # EDA Experiment B — Lead: Dhwaj (Team Leader)
#
# ## Objectives:
# - Profile address structures, missing components, street abbreviations (`Rd`, `St`, `Ave`), and landmark tokens.
# - Inspect country field distributions (US, India, and open-set handling for test France).
# - Analyze ground-truth cardinality distribution in `train_ground_truth.tsv` (distribution of 0, 1, and >1 matches per Source 1 entity).
# - Profile address token overlap between true match pairs to inform blocking and feature engineering.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from src.utils import load_config, load_ground_truth

# Load configuration
config = load_config("../configs/config.yaml")
print("Project:", config["project"]["name"])

# %% [markdown]
# ### 1. Ground Truth Cardinality & Singleton Profiling
# Measure the percentage of Source 1 entities with 0 matches (singletons), exactly 1 match, or multiple matches.

# %%
# TODO [Dhwaj]: Inspect train_ground_truth.tsv distributions
# gt = load_ground_truth("../dataset/train/train_ground_truth.tsv")
# match_counts = [len(m) for m in gt.values()]
# print("Singletons:", sum(1 for c in match_counts if c == 0))
