# %% [markdown]
# # Experiments Track A — Lead: Moksh
#
# ## Focus Areas:
# 1. **Blocking Strategy A:** Name token inverted index & character prefix blocking.
# 2. **Name Similarity Features:** RapidFuzz Levenshtein, token_sort_ratio, token_set_ratio, Jaro-Winkler, TF-IDF cosine.
# 3. **ML Model Experiment A:** Baseline Logistic Regression vs. initial decision boundary.
# 4. **Threshold Experiment A:** Sweeping decision thresholds to optimize entity-level F0.5 score.
# 5. **Error Analysis A:** Dissecting false merges and false negatives attributable to business name variants.

# %%
# Environment setup and imports
from src.utils import load_config, calculate_f05
from src.features import compute_string_similarities

print("Moksh Experiments Notebook initialized.")
