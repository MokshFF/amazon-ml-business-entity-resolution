# %% [markdown]
# # Experiments Track B — Lead: Dhwaj (Team Leader)
#
# ## Focus Areas:
# 1. **Blocking Strategy B:** Country partitioning & address token indexing.
# 2. **Address & Country Features:** Address similarity, numeric postal code match, country match indicator, missing value flags.
# 3. **ML Model Experiment B:** Investigating tabular classifiers (e.g., Random Forest / Gradient Boosting) and feature ablation.
# 4. **Threshold Experiment B:** Fine-grained threshold sweep [0.50, 0.95] focused on singleton vs. multi-match precision.
# 5. **Error Analysis B:** Categorizing errors by address noise, transliteration, and landmark confusion.

# %%
# Environment setup and imports
from src.utils import load_config, calculate_f05, evaluate_entity_resolution
from src.blocking import compute_blocking_metrics

print("Dhwaj Experiments Notebook initialized.")
