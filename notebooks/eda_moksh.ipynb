# %% [markdown]
# # EDA Experiment A — Lead: Moksh
#
# ## Objectives:
# - Inspect entity name length distributions, character sets, and noise patterns across Sources 1, 2, and 3.
# - Profile legal entity suffixes (`Corp`, `Inc`, `Pvt Ltd`, etc.) and frequency of abbreviations.
# - Analyze name token frequencies and punctuation variants (`&` vs `and`).
# - Formulate safe, non-aggressive normalization hypotheses before updating `src/preprocessing.py`.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from src.utils import load_config, load_source_tsv

# Load configuration
config = load_config("../configs/config.yaml")
print("Project:", config["project"]["name"])

# %% [markdown]
# ### 1. Sample Data Inspection (Memory-Aware Chunking)
# Load small sample slices to profile name fields without exhausting RAM.

# %%
# TODO [Moksh]: Read first N rows of train_source1.tsv, train_source2.tsv, train_source3.tsv
# df_s1_sample = pd.read_csv("../dataset/train/train_source1.tsv", sep="\t", nrows=1000)
# df_s1_sample.head()
